# %% [markdown]
# #PROJECT TITLE : PUBLIC TRANSPORT EFFICIENCY ANALYSIS
#
# PHASE 5 : Project Documentation & Submission
#
# ####Documentation of the project and preparing the Public Transport Efficiency Analysis

# %% [markdown]
#  **Project Objectives:**
#         Evaluating the overall performance and efficiency of the public transport system to utilize data and analysis to inform decision-making processes related to inventory management, service delivery, and marketing strategies.
#         Determine the optimal allocation of resources, such as vehicles, personnel, and maintenance schedules.
#         Analyze routes to identify underutilized or congested segments and recommend route adjustments for improved efficiency.
#         Use data insights to enhance marketing strategies and communication with passengers for increased ridership

# %% [markdown]
# **Design Thinking:**
#       Applying the design thinking process to public transport efficiency analysis involves a human-centered approach to understanding the needs of passengers, identifying areas for improvement, and creating innovative solutions. Throughout the design thinking process, it's essential to maintain a user-centric perspective, involving passengers and stakeholders to create more effective, passenger-focused solutions for public transport efficiency analysis and for improvement.

# %% [markdown]
#  **Development Phases:**
#           The development phases for a public transport efficiency analysis project involve collecting, analyzing, and implementing
#            to improve the efficiency of the transportation system by following ways:
#
#
# 1.  **Data Collection and Preprocessing:**
#       Gather relevant data on various aspects of the public transport system, including passenger ridership, routes, schedules, vehicle maintenance, operating costs, and more.Ensure data quality by cleaning, transforming, and preparing it for analysis.
#
# 2.   **Data Analysis:**
#         Utilize statistical and data analysis tools to process and analyze the collected data.Identify key performance indicators (KPIs) such as on-time performance, passenger load, and maintenance efficiency.Perform descriptive, exploratory, and inferential analyses to gain insights into system performance.
#
# 3. **Data Visualization:**
#       Create data visualizations using graphs like bar chart, heatmap, scatterplot,etc... to present key findings and insights.Developing interactive dashboards, charts, and reports to make data  more understandable for stakeholders.Visualize trends, patterns, and anomalies in the data.

# %% [markdown]
# Insights derived from a public transport efficiency analysis can significantly impact both inventory management and marketing strategies by transport efficiency analysis can guide inventory management by optimizing resource allocation, reducing costs, and improving maintenance practices. Simultaneously, these insights can inform marketing strategies by segmenting passengers, personalizing promotions, enhancing the passenger experience, and improving communication, all of which can lead to increased ridership and improved public transport efficiency.

# %% [markdown]
# ### MOUNTNG DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### SAMPLE IMAGE

# %% [markdown]
# A public transport efficiency project aims to improve the effectiveness and sustainability of a city or region's public transportation system. Such projects typically involve a combination of technological, infrastructural, and policy-based interventions. Here's a breakdown of key components and strategies that could be part of a public transport efficiency project.
#   Here is the iimage that the sample of image for public transport analysis.

# %%
from google.colab import files
uploaded = files.upload()
for filename in uploaded.keys():
    print(f'Uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
    from PIL import Image
from IPython.display import display
image_path = list(uploaded.keys())[0]
image = Image.open(image_path)
display(image)
# Out:
#      <input type="file" id="files-80946e89-ce9b-4b6b-a6b7-2e3fcf0c7207" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80946e89-ce9b-4b6b-a6b7-2e3fcf0c7207">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ### LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/Public Transport.csv')
df
# Out:
#          TripID RouteID  StopID                    StopName     WeekBeginning  \
# 0         23631     100   14156                181 Cross Rd  30-06-2013 00:00
# 1         23631     100   14144                177 Cross Rd  30-06-2013 00:00
# 2         23632     100   14132                175 Cross Rd  30-06-2013 00:00
# 3         23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# 4         23633     100   14147                178 Cross Rd  30-06-2013 00:00
# ...         ...     ...     ...                         ...               ...
# 1048570   45682     171   13929              8 Fullarton Rd  29-09-2013 00:00
# 1048571   45682     171   13758            3 Glen Osmond Rd  29-09-2013 00:00
# 1048572   45682     171   13967              9 Fullarton Rd  29-09-2013 00:00
# 1048573   45682     171   13808              5 Fullarton Rd  29-09-2013 00:00
# 1048574   45682     171   13845              6 Fullarton Rd  29-09-2013 00:00
#
#          NumberOfBoardings
# ...

# %%
df.describe()
# Out:
#              TripID        StopID  NumberOfBoardings
# count  1.048575e+06  1.048575e+06       1.048575e+06
# mean   2.860299e+04  1.330114e+04       4.132290e+00
# std    1.674656e+04  1.119243e+03       6.291338e+00
# min    3.017000e+03  1.081700e+04       1.000000e+00
# 25%    1.162200e+04  1.269800e+04       1.000000e+00
# 50%    3.423400e+04  1.333500e+04       2.000000e+00
# 75%    4.512600e+04  1.371600e+04       4.000000e+00
# max    6.258500e+04  1.849300e+04       1.930000e+02

# %% [markdown]
# ## DATA PRE-PROCESSING TECHNIQUES

# %% [markdown]
#  It is a crucial step in any data analysis project, including public transport analysis. It involves cleaning, transforming, and organizing raw data into a format suitable for analysis. Here are steps you can take for data preprocessing in public transport analysis:
#
# 1.   Data Cleaning
# 2.   Handling missing values
# 3.   Data Transformation
# 4.   Data reduction

# %% [markdown]
# Checking the datatypes.

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# From the dataset that, we are calculating the statistical values and deleting the duplicated values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 6 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   TripID             1048575 non-null  int64
#  1   RouteID            1048575 non-null  object
#  2   StopID             1048575 non-null  int64
#  3   StopName           1048575 non-null  object
#  4   WeekBeginning      1048575 non-null  object
#  5   NumberOfBoardings  1048575 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 48.0+ MB

# %% [markdown]
# Finding the missing values.

# %%
df.isnull().sum()
# Out:
# TripID               0
# RouteID              0
# StopID               0
# StopName             0
# WeekBeginning        0
# NumberOfBoardings    0
# dtype: int64

# %% [markdown]
# Checking the duplicate values.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## DATA TRANSFORMATION

# %% [markdown]
# Findng the average count of passengers per Stop using there StopID,StopName and also WeekBoarding's using by the cross-tabulation.

# %%
print('\n average count per route and Stop names\n')
df['StopID'] = pd.to_datetime(df['StopID'])
df_daily_aggregated = df.groupby(pd.Grouper(key='StopID', freq='D')).sum().reset_index()
print("\nDataFrame with daily aggregation:")
print(df_daily_aggregated)
df_route_avg = df.groupby('StopName')['TripID'].mean().reset_index()
print("\nAverage Passenger Count per Route:")
print(df_route_avg)
pivot_table = df.pivot_table(index='StopID', columns='StopName', values='TripID', aggfunc='sum')
print("\nPivot Table (Cross-tabulation):")
print(pivot_table)
# Out:
#  average count per route and Stop names
#
#
# DataFrame with daily aggregation:
#       StopID       TripID  NumberOfBoardings
# 0 1970-01-01  29992383732            4333016
#
# Average Passenger Count per Route:
#                            StopName        TripID
# 0                       1 Anzac Hwy  31019.137553
# 1                    1 Fullarton Rd  26140.483029
# 2                       1 George St  28377.026277
# 3                  1 Glen Osmond Rd  45700.768581
# 4                 1 Henley Beach Rd  30380.386707
# ..                              ...           ...
# 578  Zone B Registry Rd Flinders Un  14599.031056
# 579   Zone B West Lakes Interchange  27447.951355
# 580               Zone C Moseley St  31263.491906
# 581      Zone D Arndale Interchange  44698.666667
# 582  Zone D Port Adelaide Interchan  27268.060319
#
# [583 rows x 2 columns]
#
# Pivot Table (Cross-tabulation):
# StopName                       1 Anzac Hwy  1 Fullarton Rd  1 George St  \
# StopID
# ...

# %% [markdown]
# ## DATA REDUTION

# %% [markdown]
# Here , the process for aggregating the data based on the Weekly Boarding  stops per route.

# %%
print("\nSampled DataFrame:\n")
print(df)
df['WeekBeginning'] = pd.to_datetime(df['WeekBeginning'])
df_weekly_aggregated = df.groupby(pd.Grouper(key='WeekBeginning', freq='W')).sum().reset_index()
print("\nDataFrame with weekly aggregation:")
print(df_weekly_aggregated)
# Out:
# Sampled DataFrame:
#
#          TripID RouteID                        StopID  \
# 0         23631     100 1970-01-01 00:00:00.000014156
# 1         23631     100 1970-01-01 00:00:00.000014144
# 2         23632     100 1970-01-01 00:00:00.000014132
# 3         23633     100 1970-01-01 00:00:00.000012266
# 4         23633     100 1970-01-01 00:00:00.000014147
# ...         ...     ...                           ...
# 1048570   45682     171 1970-01-01 00:00:00.000013929
# 1048571   45682     171 1970-01-01 00:00:00.000013758
# 1048572   45682     171 1970-01-01 00:00:00.000013967
# 1048573   45682     171 1970-01-01 00:00:00.000013808
# 1048574   45682     171 1970-01-01 00:00:00.000013845
#
#                            StopName     WeekBeginning  NumberOfBoardings
# 0                      181 Cross Rd  30-06-2013 00:00                  1
# 1                      177 Cross Rd  30-06-2013 00:00                  1
# 2                      175 Cross Rd  30-06-2013 00:00                  1
# ...

# %%
sns.pairplot(df,corner=True)
plt.title("\n PairPlot \n")
plt.show()

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df.corr(),annot=True,cmap='pink')
plt.title("\n  Correlation between NumberoFBoardings Using TripID ! \n")
plt.plot()
# Out:
# []

# %% [markdown]
# # FEATURE ENGINEERING & MODEL TRAINING
#
#
# 1.   Here Training & Testing the model using Supervised machine learning algorithms like as Linear regression , DecisionTreeregression , randomforest , Logistic regression & SVM(support vector machine).
# 2.   Here performing different activities like feature engineering, model training, evaluation etc as per the instructions in the project.
# 3. Label Encoding the data for training  and testing the data

# %% [markdown]
# LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['StopName']=le.fit_transform(df['StopName'])
df['StopID']=le.fit_transform(df['StopID'])
df
# Out:
#          TripID RouteID  StopID  StopName WeekBeginning  NumberOfBoardings
# 0         23631     100     787       148    2013-06-30                  1
# 1         23631     100     779       133    2013-06-30                  1
# 2         23632     100     771       131    2013-06-30                  1
# 3         23633     100     146       572    2013-06-30                  2
# 4         23633     100     781       134    2013-06-30                  1
# ...         ...     ...     ...       ...           ...                ...
# 1048570   45682     171     671       412    2013-09-29                  2
# 1048571   45682     171     593       260    2013-09-29                  3
# 1048572   45682     171     690       436    2013-09-29                  1
# 1048573   45682     171     620       358    2013-09-29                  1
# 1048574   45682     171     632       383    2013-09-29                  3
#
# [1048575 rows x 6 columns]

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score

# %% [markdown]
# ####Model Selection for train_test_split

# %%
X = df.drop('TripID',axis=1)
y = df['WeekBeginning']

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
train=pd.read_csv('/content/drive/MyDrive/Public Transport.csv')
test=pd.read_csv('/content/drive/MyDrive/Public Transport.csv')
train.head(),test.head()
# Out:
# (   TripID RouteID  StopID                    StopName     WeekBeginning  \
#  0   23631     100   14156                181 Cross Rd  30-06-2013 00:00
#  1   23631     100   14144                177 Cross Rd  30-06-2013 00:00
#  2   23632     100   14132                175 Cross Rd  30-06-2013 00:00
#  3   23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
#  4   23633     100   14147                178 Cross Rd  30-06-2013 00:00
#
#     NumberOfBoardings
#  0                  1
#  1                  1
#  2                  1
#  3                  2
#  4                  1  ,
#     TripID RouteID  StopID                    StopName     WeekBeginning  \
#  0   23631     100   14156                181 Cross Rd  30-06-2013 00:00
#  1   23631     100   14144                177 Cross Rd  30-06-2013 00:00
#  2   23632     100   14132                175 Cross Rd  30-06-2013 00:00
#  3   23633     100   12266  Zone A Arndale Interchange  30-06-2013 00:00
# ...

# %%
train.isnull().sum()
print("Train Shape:",train.shape)
test.isnull().sum()
print("Test Shape:",test.shape)
# Out:
# Train Shape: (1048575, 6)
# Test Shape: (1048575, 6)

# %%
mean=df.mean
mean()
# Out:
# TripID               28602.993331
# StopID                 386.683629
# StopName               300.829945
# NumberOfBoardings        4.132290
# dtype: float64

# %% [markdown]
# #PERFORMING EDA-ANALYSIS
#  Here we are analysis the data based on numberofBoardings , RouteID , week beginnings analysis .

# %%
print("\n BarChart analysis using the StopID vs TripID vs NumberOfBoardings ! \n")
fig=px.bar(df.head(100), x="NumberOfBoardings",y="StopName",color="TripID",template="ggplot2")
fig.show()
# Out:
#  BarChart analysis using the StopID vs TripID vs NumberOfBoardings !
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Explore correlations between features and the target variable

# %%
corr_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('\n Correlation Matrix \n')
plt.show()

# %% [markdown]
# ### Scatter plots for potential influential features
# #####Attributes are using to visualise the plot is StopID and NumberOfBoardings

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x='StopID', y='NumberOfBoardings', data=df)
plt.title("\n Scatterplot using StopID vs. No.of Boardings \n")
#plt.title('StopID vs. No.of Boardings')
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x='StopName', y='NumberOfBoardings', data=df)
plt.title('\n Scatterplot using StopName vs. no.of Boardings \n')
plt.show()

# %% [markdown]
# ### Boxplots for categorical variables

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='TripID', y='WeekBeginning', data=df)
plt.title('\n Boxplot using Weekly passengers by TripID vs. WeekBeginning \n')
plt.show()

# %% [markdown]
# ### Visualize the distribution of the target variable (e.g., efficiency_score)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['WeekBeginning'], kde=True)
plt.title('\n Distribution of WeekBeginning \n')
plt.show()

# %%
mean=df['NumberOfBoardings'].mean
mean()
# Out:
# 4.132290012636196

# %%
mean=df['WeekBeginning'].mean
mean()
# Out:
# Timestamp('2013-12-24 07:52:29.038267136')

# %%
mean=df['StopName'].mean
mean()
# Out:
# 300.8299454020933

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Final Conclusion of the data for Public transport efficiency analysis is a critical step that lays hte foundation for meaningfull insights and decision making.Through LabelEncoding, Transformation and Visualization, we ensure that the data accurate , complete and revalent. Proper preprocessing not only enhances the quality of analysis but also paves the way for the development of effective strategies to improve public transportation system and ultimately benefit communities and the environment.
#
#  1.The average boardings happening in the city percentage is %3.132.
#
#
#  2.The average of per week the passengers using transport service from one stop is max 300 members.
#
#
#  3.The average TimeStamp of the Weekbeginnnings is Timestamp('2013-12-24 07:52:29.038267136')
